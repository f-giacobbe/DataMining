# %%
# Prova Scritta Data Mining - Simulazione C
# Tempo a disposizione: 1 ora

# Nome:
# Cognome:
# Matricola:

# %% [markdown]
# # Esercizio 1
#
# Carica il dataset *iris* da scikit-learn in un oggetto Pandas DataFrame, ed esegui le seguenti operazioni:
# - Visualizza le principali informazioni del DataFrame (data types, utilizzo memoria, valori non-NA)
# - Visualizza le statistiche di base del DataFrame (count, mean, std ...)
# - Stampa le prime 10 righe del DataFrame
# - Visualizza un grafico a barre che mostri i valori medi di ciascuna feature
# - Applica il k-means per raggruppare i record in 3 cluster e stampa l'inerzia ottenuta

# %% [markdown]
# # Esercizio 2
#
# Utilizza il dataset *breast_cancer* per addestrare un KNN e un Random Forest Classifier per predire la classe target. Di seguito istruzioni dettagliate:
# - Utilizza l'80% dei dati per il training, il 20% per il test
# - Definisci un KNN con numero di neighbor pari a 9
# - Definisci un Random Forest composto da 40 alberi decisionali
# - Stampa la F1 score per entrambi i modelli
# - Definisci un Voting Classifier che combini i due modelli (**soft** voting) e stampa la F1 score del Voting Classifier

# %% [markdown]
# # Esercizio 3
#
# Definisci una rete neurale artificiale con le seguenti caratteristiche:
# - 30 neuroni in input
# - Layer nascosto con 64 neuroni con funzione di attivazione ReLU (nn.ReLU o F.relu)
# - Layer nascosto con 8 neuroni e funzione di attivazione ReLU
# - Output layer di dimensione 2 e funzione di attivazione Softmax
#
# Infine, si richiede di implementare il corrispondente metodo forward per poter utilizzare la rete definita.
