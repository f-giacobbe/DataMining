# %%
# Prova Scritta Data Mining - Simulazione B
# Tempo a disposizione: 1 ora

# Nome:
# Cognome:
# Matricola:

# %% [markdown]
# # Esercizio 1
#
# Carica il dataset *California housing* da scikit-learn in un oggetto Pandas DataFrame, ed esegui le seguenti operazioni:
# - Visualizza le principali informazioni del DataFrame (data types, utilizzo memoria, valori non-NA)
# - Visualizza le statistiche di base del DataFrame (count, mean, std ...)
# - Stampa le ultime 10 righe del DataFrame
# - Visualizza un istogramma dell'attributo 'AveRooms' (numero medio di stanze)
# - Applica il k-means per raggruppare i record in 5 cluster e stampa l'inerzia ottenuta

# %% [markdown]
# # Esercizio 2
#
# Utilizza il dataset *digits* per addestrare un SVM e un Random Forest Classifier per predire la cifra. Di seguito istruzioni dettagliate:
# - Utilizza l'80% dei dati per il training, il 20% per il test
# - Definisci un SVM con kernel lineare
# - Definisci un Random Forest composto da 60 alberi decisionali
# - Stampa la F1 score (average 'macro') per entrambi i modelli
# - Definisci un Voting Classifier che combini i due modelli (hard voting) e stampa la F1 score del Voting Classifier

# %% [markdown]
# # Esercizio 3
#
# Definisci una rete neurale artificiale con le seguenti caratteristiche:
# - 64 neuroni in input
# - Layer nascosto con 32 neuroni con funzione di attivazione ReLU (nn.ReLU o F.relu)
# - Layer nascosto con 16 neuroni e funzione di attivazione ReLU
# - Output layer di dimensione 10 e funzione di attivazione Softmax
#
# Infine, si richiede di implementare il corrispondente metodo forward per poter utilizzare la rete definita.
